# %%
import numpy
from qutip.visualization import hinton, plot_fock_distribution, plot_wigner_fock_distribution
from GHZ_state.GHZ_circuit_with_qutip import create_fig_3_GHZ_circuit, create_IBM_GHZ_circuit, run_qubit_circuit

# %%
numpy.random.seed(42)
for _ in range(5):
    rho = run_qubit_circuit(create_fig_3_GHZ_circuit())
    hinton(rho)
    plot_wigner_fock_distribution(rho)
# Out:
# phis =  [2.35330497 5.97351416 4.59925358 3.76148219 0.98029403 0.98014248]
# phis =  [0.3649501  5.44234523 3.77691701 4.44895122 0.12933619 6.09412333]
# phis =  [5.23039137 1.33416598 1.14243996 1.15236452 1.91161039 3.2971419 ]
# phis =  [2.71399059 1.82984665 3.84438512 0.87646578 1.83559896 2.30191935]
# phis =  [2.86557222 4.93340606 1.25458737 3.23103027 3.72225051 0.29185655]

# %%
# not as interesting (nor fun) as the above as the gates do not have a random angle, but here it is anyway
hinton(run_qubit_circuit(create_IBM_GHZ_circuit()))
# Out:
# (<Figure size 576x432 with 2 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x12acb0d30>)

# %%
from qutip.ipynbtools import version_table
version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>QuTiP</td><td>4.6.0.dev0+4f9b04b1</td></tr><tr><td>Numpy</td><td>1.19.0</td></tr><tr><td>SciPy</td><td>1.5.1</td></tr><tr><td>matplotlib</td><td>3.2.2</td></tr><tr><td>Cython</td><td>0.29.21</td></tr><tr><td>Number of CPUs</td><td>6</td></tr><tr><td>BLAS Info</td><td>OPENBLAS</td></tr><tr><td>IPython</td><td>7.16.1</td></tr><tr><td>Python</td><td>3.7.3 (default, Dec 13 2019, 19:58:14)
# [Clang 11.0.0 (clang-1100.0.33.17)]</td></tr><tr><td>OS</td><td>posix [darwin]</td></tr><tr><td colspan='2'>Thu Jul 16 23:22:06 2020 BST</td></tr></table>
